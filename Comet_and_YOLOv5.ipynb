# %% [markdown]
# <a href="https://colab.research.google.com/github/ever4ever-ing/ML_train/blob/main/Comet_and_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://cdn.comet.ml/img/notebook_logo.png">
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab) builds tools that help data scientists, engineers, and team leaders accelerate and optimize machine learning and deep learning models.
#
# Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)!
#
# Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# If you'd like to learn more about Comet checkout our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)

# %% [markdown]
# # Install Comet

# %%
# %pip install comet_ml --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.6/710.6 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.3/980.3 kB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 6.9 MB/s eta 0:00:00

# %% [markdown]
# # Initialize Comet

# %%
import comet_ml
comet_ml.init(project_name='comet-example-yolov5')
# Out:
# COMET WARNING: comet_ml.init() is deprecated and will be removed soon. Please use comet_ml.login()
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# # Setup YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17120, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 17120 (delta 35), reused 16 (delta 12), pack-reused 17056 (from 3)
# Receiving objects: 100% (17120/17120), 15.79 MiB | 12.92 MiB/s, done.
# Resolving deltas: 100% (11742/11742), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 51.4 MB/s eta 0:00:00

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %% [markdown]
# # Run the Training Script

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --bbox_interval 1 --weights yolov5s.pt
# Out:
# 2025-01-10 19:03:49.551868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:03:49.583367: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:03:49.592820: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/f0e2f863e3174d32aed615461becc055
#
#
# Dataset not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/coco128.zip to coco128.zip...
# 100% 6.66M/6.66M [00:00<00:00, 285MB/s]
# Dataset download success ✅ (1.6s), saved to /content/datasets
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 107MB/s]
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# WARNING ⚠️ NMS time limit 0.550s exceeded
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<00:00, 1523.88it/s]
# train: New cache created: /content/datasets/coco128/labels/train2017.cache
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:03<00:21,  3.13s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:03<00:09,  1.51s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:03<00:04,  1.04it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:04<00:02,  1.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:04<00:02,  1.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:05<00:01,  1.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:05<00:00,  1.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/2      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:05<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:13<00:00,  3.32s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:02,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04264    0.07199    0.01399        245        640:  25% 2/8 [00:00<00:02,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04407    0.07896    0.01574        286        640:  38% 3/8 [00:01<00:01,  2.75it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04424    0.07652    0.01582        233        640:  50% 4/8 [00:01<00:01,  2.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G     0.0448    0.07581    0.01692        249        640:  62% 5/8 [00:01<00:01,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04429    0.07325     0.0168        195        640:  75% 6/8 [00:02<00:00,  2.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04436    0.07376    0.01688        267        640:  88% 7/8 [00:02<00:00,  2.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.61G    0.04367    0.07197    0.01642        199        640: 100% 8/8 [00:03<00:00,  2.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.38s/it]
#                    all        128        929      0.716      0.626       0.71      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G     0.0459     0.0626    0.01276        237        640:  12% 1/8 [00:00<00:01,  3.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G     0.0449    0.05678    0.01539        185        640:  25% 2/8 [00:00<00:01,  3.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G    0.04412    0.05497    0.01565        162        640:  38% 3/8 [00:00<00:01,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G    0.04534      0.062    0.01668        303        640:  50% 4/8 [00:01<00:01,  3.71it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G     0.0454    0.06505    0.01655        226        640:  62% 5/8 [00:01<00:00,  3.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G    0.04545    0.06713    0.01625        251        640:  75% 6/8 [00:01<00:00,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G    0.04535    0.06653     0.0164        184        640:  88% 7/8 [00:01<00:00,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/2      4.61G    0.04511    0.06581    0.01651        193        640: 100% 8/8 [00:02<00:00,  3.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.96it/s]
#                    all        128        929      0.727      0.636      0.726      0.486
#
# 3 epochs completed in 0.010 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.8MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.03it/s]
#                    all        128        929      0.727      0.636      0.727      0.487
#                 person        128        254      0.867       0.72      0.808      0.526
#                bicycle        128          6      0.564      0.333      0.592      0.345
#                    car        128         46       0.82      0.397      0.553      0.237
#             motorcycle        128          5      0.689          1      0.862      0.586
#               airplane        128          6      0.972          1      0.995      0.688
#                    bus        128          7      0.569      0.714      0.781      0.672
#                  train        128          3          1       0.57      0.913      0.611
#                  truck        128         12      0.647      0.333      0.462      0.252
#                   boat        128          6      0.722      0.333      0.467      0.224
#          traffic light        128         14      0.612      0.227      0.365      0.197
#              stop sign        128          2      0.811          1      0.995      0.796
#                  bench        128          9       0.69      0.499      0.665      0.296
#                   bird        128         16      0.961          1      0.995      0.648
#                    cat        128          4      0.887          1      0.995      0.797
#                    dog        128          9      0.968      0.667      0.869      0.621
#                  horse        128          2      0.834          1      0.995      0.622
#               elephant        128         17      0.972      0.882      0.934      0.728
#                   bear        128          1      0.683          1      0.995      0.995
#                  zebra        128          4      0.856          1      0.995       0.96
#                giraffe        128          9      0.784      0.809      0.902      0.667
#               backpack        128          6      0.867        0.5      0.753      0.339
#               umbrella        128         18       0.86      0.778      0.884      0.507
#                handbag        128         19      0.697      0.263      0.335      0.184
#                    tie        128          7      0.767      0.714      0.787       0.49
#               suitcase        128          4      0.655          1      0.945      0.606
#                frisbee        128          5      0.718        0.8      0.759       0.66
#                   skis        128          1          0          0     0.0585     0.0138
#              snowboard        128          7      0.819      0.654      0.829      0.528
#            sports ball        128          6      0.598      0.667      0.602      0.327
#                   kite        128         10       0.74        0.6      0.611      0.235
#           baseball bat        128          4      0.635        0.5      0.535        0.2
#         baseball glove        128          7      0.482      0.429      0.469      0.299
#             skateboard        128          5          1       0.59      0.707      0.455
#          tennis racket        128          7      0.609      0.429      0.504      0.303
#                 bottle        128         18      0.578      0.381      0.553      0.267
#             wine glass        128         16      0.734      0.875      0.874      0.475
#                    cup        128         36      0.842      0.738      0.815      0.519
#                   fork        128          6          1      0.315      0.456      0.303
#                  knife        128         16      0.766      0.615       0.71      0.438
#                  spoon        128         22      0.718      0.455      0.624      0.361
#                   bowl        128         28      0.753      0.607      0.722      0.548
#                 banana        128          1      0.913          1      0.995      0.301
#               sandwich        128          2          1          0      0.606      0.535
#                 orange        128          4       0.69          1      0.995       0.66
#               broccoli        128         11      0.414      0.455      0.437      0.333
#                 carrot        128         24      0.618      0.667      0.737      0.499
#                hot dog        128          2      0.395          1      0.995      0.846
#                  pizza        128          5      0.827          1      0.962      0.714
#                  donut        128         14      0.634          1      0.944      0.806
#                   cake        128          4      0.866          1      0.995      0.822
#                  chair        128         35      0.595      0.629      0.607      0.321
#                  couch        128          6      0.871      0.667      0.855      0.549
#           potted plant        128         14      0.713      0.786      0.835      0.495
#                    bed        128          3      0.401      0.267      0.746      0.399
#           dining table        128         13      0.824      0.363      0.585      0.335
#                 toilet        128          2      0.789          1      0.995      0.846
#                     tv        128          2      0.589          1      0.995      0.846
#                 laptop        128          3          1          0      0.602      0.301
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.618      0.629      0.538
#             cell phone        128          8      0.378       0.25      0.344      0.186
#              microwave        128          3      0.755          1      0.995      0.778
#                   oven        128          5       0.36        0.4      0.434      0.265
#                   sink        128          6      0.465      0.333      0.351      0.245
#           refrigerator        128          5      0.563        0.8      0.799      0.533
#                   book        128         29      0.518      0.207       0.35      0.179
#                  clock        128          9      0.768      0.889      0.916      0.721
#                   vase        128          2      0.319          1      0.995      0.821
#               scissors        128          1          1          0      0.497     0.0498
#             teddy bear        128         21      0.818      0.642      0.791      0.522
#             toothbrush        128          5      0.803      0.817      0.928      0.577
# Results saved to runs/train/exp
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/f0e2f863e3174d32aed615461becc055
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [3]                 : (1.8858516216278076, 2.5456433296203613)
# COMET INFO:     metrics/mAP_0.5 [6]      : (0.6835440624486755, 0.726034634470304)
# COMET INFO:     metrics/mAP_0.5:0.95 [6] : (0.457556602492091, 0.4864841979807111)
# COMET INFO:     metrics/precision [6]    : (0.6791493683461854, 0.7265791610031552)
# COMET INFO:     metrics/recall [6]       : (0.605375524096936, 0.635877762037897)
# COMET INFO:     train/box_loss [6]       : (0.043669551610946655, 0.04529991000890732)
# COMET INFO:     train/cls_loss [6]       : (0.016418561339378357, 0.018179820850491524)
# COMET INFO:     train/obj_loss [6]       : (0.06486806273460388, 0.07196730375289917)
# COMET INFO:     val/box_loss [6]         : (0.0399678535759449, 0.041134096682071686)
# COMET INFO:     val/cls_loss [6]         : (0.00881195068359375, 0.010472774505615234)
# COMET INFO:     val/obj_loss [6]         : (0.037041664123535156, 0.03827667236328125)
# COMET INFO:     x/lr0 [6]                : (0.077782, 0.0937)
# COMET INFO:     x/lr1 [6]                : (0.0007, 0.001005)
# COMET INFO:     x/lr2 [6]                : (0.0007, 0.001005)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/f0e2f863e3174d32aed615461becc055
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.97 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: All assets have been sent, waiting for delivery confirmation

# %% [markdown]
# # Configure Comet Logging

# %% [markdown]
# ## Logging Checkpoints with Comet
#
# Logging Models to Comet is disabled by default. To enable it, pass the `save-period` argument to the training script. This will save the
# logged checkpoints to Comet based on the interval value provided by `save-period`
#
# Checkpoints can be found in the [Assets and Artifacts](https://www.comet.com/examples/comet-example-yolov5/a0e29e0e9b984e4a822db2a62d0cb357?experiment-tab=assets?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab) tab in your Experiment

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1 \
--save-period 1
# Out:
# 2025-01-10 19:07:58.259970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:07:58.293568: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:07:58.303799: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/deae175e4f494a7bb3cb0d08e2dfacc9
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp3/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:03<00:23,  3.41s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:03<00:09,  1.61s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:04<00:05,  1.03s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:04<00:03,  1.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:05<00:02,  1.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:05<00:01,  1.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:05<00:00,  2.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:05<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:12<00:00,  3.03s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:01,  3.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04263    0.07197    0.01398        245        640:  25% 2/8 [00:00<00:01,  3.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04406    0.07894    0.01572        286        640:  38% 3/8 [00:00<00:01,  3.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04423    0.07648    0.01579        233        640:  50% 4/8 [00:01<00:01,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04478    0.07575    0.01688        249        640:  62% 5/8 [00:01<00:01,  2.84it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04428     0.0732    0.01676        195        640:  75% 6/8 [00:02<00:00,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04435    0.07369    0.01683        267        640:  88% 7/8 [00:02<00:00,  3.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04366     0.0719    0.01638        199        640: 100% 8/8 [00:02<00:00,  3.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.10it/s]
#                    all        128        929      0.723      0.621       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04583    0.06229    0.01254        237        640:  12% 1/8 [00:00<00:02,  3.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04489    0.05657    0.01523        185        640:  25% 2/8 [00:00<00:01,  3.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0441    0.05478    0.01548        162        640:  38% 3/8 [00:01<00:02,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0453    0.06179    0.01648        303        640:  50% 4/8 [00:01<00:01,  2.01it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04536    0.06484    0.01636        226        640:  62% 5/8 [00:02<00:01,  1.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04539    0.06687    0.01604        251        640:  75% 6/8 [00:02<00:00,  2.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04528     0.0663     0.0162        184        640:  88% 7/8 [00:03<00:00,  1.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04507     0.0656    0.01631        193        640: 100% 8/8 [00:04<00:00,  1.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.20s/it]
#                    all        128        929      0.733      0.645      0.733      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04488     0.0617    0.02394        170        640:  12% 1/8 [00:00<00:02,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04242    0.06038    0.01826        202        640:  25% 2/8 [00:00<00:02,  2.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04176    0.05809    0.01751        169        640:  38% 3/8 [00:01<00:01,  2.86it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04303    0.05972    0.01753        209        640:  50% 4/8 [00:01<00:01,  3.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04392      0.066    0.01701        328        640:  62% 5/8 [00:01<00:01,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G     0.0445    0.06547    0.01778        252        640:  75% 6/8 [00:01<00:00,  3.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04376    0.06194    0.01738        125        640:  88% 7/8 [00:02<00:00,  2.74it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04383    0.06209    0.01732        225        640: 100% 8/8 [00:02<00:00,  2.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.59it/s]
#                    all        128        929      0.759      0.643      0.754      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04041    0.04643    0.01356        166        640:  12% 1/8 [00:00<00:02,  3.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04241    0.05219    0.01217        195        640:  25% 2/8 [00:00<00:01,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G     0.0435    0.05565    0.01361        215        640:  38% 3/8 [00:00<00:01,  3.05it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04368    0.05314    0.01396        143        640:  50% 4/8 [00:01<00:01,  3.03it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04296    0.05456    0.01419        181        640:  62% 5/8 [00:01<00:01,  2.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04334     0.0532     0.0154        148        640:  75% 6/8 [00:02<00:00,  2.81it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04302    0.05461    0.01539        235        640:  88% 7/8 [00:02<00:00,  2.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04344    0.05496    0.01539        199        640: 100% 8/8 [00:02<00:00,  2.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.24it/s]
#                    all        128        929      0.728      0.689      0.764       0.51
#
# 5 epochs completed in 0.015 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 14.8MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.15s/it]
#                    all        128        929      0.729       0.69      0.764       0.51
#                 person        128        254      0.841      0.713       0.81      0.539
#                bicycle        128          6          1      0.667      0.808      0.392
#                    car        128         46      0.681      0.457       0.58      0.242
#             motorcycle        128          5      0.774          1      0.928      0.702
#               airplane        128          6      0.926          1      0.995      0.707
#                    bus        128          7      0.659      0.714      0.722       0.65
#                  train        128          3      0.622      0.577       0.83      0.496
#                  truck        128         12      0.764        0.5      0.557      0.296
#                   boat        128          6      0.868      0.333      0.507      0.213
#          traffic light        128         14      0.801      0.288      0.422      0.232
#              stop sign        128          2      0.738          1      0.995      0.846
#                  bench        128          9      0.618      0.667       0.68      0.312
#                   bird        128         16      0.908          1      0.995      0.662
#                    cat        128          4      0.836          1      0.995      0.821
#                    dog        128          9          1      0.688      0.955      0.706
#                  horse        128          2      0.779          1      0.995      0.647
#               elephant        128         17      0.962      0.882      0.936      0.719
#                   bear        128          1      0.666          1      0.995      0.995
#                  zebra        128          4      0.865          1      0.995       0.91
#                giraffe        128          9      0.836      0.889      0.951      0.724
#               backpack        128          6      0.705      0.667      0.787      0.365
#               umbrella        128         18      0.808      0.703      0.894      0.514
#                handbag        128         19      0.662      0.316      0.415       0.24
#                    tie        128          7      0.742      0.714      0.822      0.515
#               suitcase        128          4      0.812          1      0.995      0.592
#                frisbee        128          5      0.704        0.8        0.8       0.66
#                   skis        128          1      0.647          1      0.995      0.398
#              snowboard        128          7      0.845      0.714      0.876      0.591
#            sports ball        128          6      0.599      0.667      0.602      0.324
#                   kite        128         10      0.561        0.7      0.582      0.226
#           baseball bat        128          4      0.531        0.5      0.528      0.189
#         baseball glove        128          7      0.533      0.429      0.475        0.3
#             skateboard        128          5      0.728      0.547      0.686      0.471
#          tennis racket        128          7       0.53      0.489       0.55      0.305
#                 bottle        128         18      0.543      0.444      0.567      0.269
#             wine glass        128         16       0.68      0.938      0.886      0.472
#                    cup        128         36      0.739       0.75      0.847      0.539
#                   fork        128          6          1      0.316      0.508      0.282
#                  knife        128         16      0.742      0.625      0.714      0.418
#                  spoon        128         22      0.612      0.502      0.618      0.358
#                   bowl        128         28      0.667      0.607      0.748      0.571
#                 banana        128          1      0.825          1      0.995      0.207
#               sandwich        128          2          1          0       0.39      0.337
#                 orange        128          4      0.592          1      0.995      0.652
#               broccoli        128         11      0.237      0.545      0.548       0.38
#                 carrot        128         24      0.592      0.875      0.786      0.532
#                hot dog        128          2      0.391          1      0.995       0.92
#                  pizza        128          5      0.818        0.8      0.962      0.716
#                  donut        128         14      0.634          1       0.95      0.834
#                   cake        128          4      0.859          1      0.995      0.846
#                  chair        128         35      0.564      0.686      0.626      0.341
#                  couch        128          6          1      0.776      0.895      0.552
#           potted plant        128         14      0.693      0.857      0.842      0.506
#                    bed        128          3      0.882      0.667      0.913      0.614
#           dining table        128         13       0.74      0.439      0.584      0.349
#                 toilet        128          2      0.748          1      0.995      0.846
#                     tv        128          2      0.674          1      0.995      0.895
#                 laptop        128          3          1          0       0.83      0.482
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.624       0.63      0.549
#             cell phone        128          8      0.482      0.375      0.395      0.218
#              microwave        128          3       0.79          1      0.995        0.8
#                   oven        128          5      0.339        0.4      0.435      0.275
#                   sink        128          6      0.422       0.37      0.461      0.337
#           refrigerator        128          5      0.567        0.8      0.806      0.546
#                   book        128         29      0.563      0.267      0.369       0.19
#                  clock        128          9      0.781      0.889       0.93      0.723
#                   vase        128          2      0.449          1      0.995      0.821
#               scissors        128          1          1          0      0.497      0.104
#             teddy bear        128         21      0.809      0.806      0.864      0.553
#             toothbrush        128          5      0.763          1      0.995       0.67
# Results saved to runs/train/exp3
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/deae175e4f494a7bb3cb0d08e2dfacc9
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.5215718746185303, 2.5443503856658936)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6835440624486755, 0.7638775005200609)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.457556602492091, 0.5102440527964537)
# COMET INFO:     metrics/precision [10]    : (0.6791493683461854, 0.7588899757733395)
# COMET INFO:     metrics/recall [10]       : (0.605375524096936, 0.6892090470681517)
# COMET INFO:     train/box_loss [10]       : (0.043435562402009964, 0.04529991000890732)
# COMET INFO:     train/cls_loss [10]       : (0.015392707660794258, 0.018179820850491524)
# COMET INFO:     train/obj_loss [10]       : (0.054962024092674255, 0.07189694046974182)
# COMET INFO:     val/box_loss [10]         : (0.039035994559526443, 0.041134096682071686)
# COMET INFO:     val/cls_loss [10]         : (0.007620334625244141, 0.010472774505615234)
# COMET INFO:     val/obj_loss [10]         : (0.03592967987060547, 0.03827667236328125)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/deae175e4f494a7bb3cb0d08e2dfacc9
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp3
# COMET INFO:     save_period         : 1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.88 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     model-element       : 19 (1018.52 MB)
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 2 file(s), remaining 13.40 MB/14.85 MB

# %% [markdown]
# ## Logging Model Predictions
#
# You can log model predictions and the associated images by passing the `bbox_interval` command line argument. Predictions can be visualized using Comet's Object Detection Custom Panel
#
# **Note:** The YOLOv5 validation dataloader will default to a batch size of 32, so you will have to set the logging frequency accordingly.
#
# Here is an [example project using the Panel](https://www.comet.com/examples/comet-example-yolov5/view/1c4Dqcu8mZ767NBipjwlx3gz6/panels?shareable=YcwMiJaZSXfcEXpGOHDD12vA1&utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab)

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1
# Out:
# 2025-01-10 19:09:47.413787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:09:47.433341: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:09:47.439308: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/f2449089a6f241a08c8e07861c81bebf
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# WARNING ⚠️ NMS time limit 0.550s exceeded
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:03<00:27,  3.91s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:04<00:11,  1.88s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:04<00:06,  1.25s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:05<00:04,  1.01s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:06<00:02,  1.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:06<00:01,  1.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:07<00:00,  1.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:07<00:00,  1.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:11<00:00,  2.77s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:02,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04263    0.07197    0.01398        245        640:  25% 2/8 [00:00<00:02,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04406    0.07894    0.01572        286        640:  38% 3/8 [00:01<00:01,  2.71it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04423    0.07648    0.01579        233        640:  50% 4/8 [00:01<00:01,  2.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04478    0.07575    0.01688        249        640:  62% 5/8 [00:01<00:01,  2.68it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04428     0.0732    0.01676        195        640:  75% 6/8 [00:02<00:00,  2.64it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04435    0.07369    0.01683        267        640:  88% 7/8 [00:03<00:00,  1.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04366     0.0719    0.01638        199        640: 100% 8/8 [00:03<00:00,  2.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.37s/it]
#                    all        128        929      0.723      0.621       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04583    0.06229    0.01254        237        640:  12% 1/8 [00:00<00:01,  3.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04489    0.05657    0.01523        185        640:  25% 2/8 [00:00<00:01,  3.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0441    0.05478    0.01548        162        640:  38% 3/8 [00:00<00:01,  3.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0453    0.06179    0.01648        303        640:  50% 4/8 [00:01<00:01,  3.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04536    0.06484    0.01636        226        640:  62% 5/8 [00:01<00:00,  3.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04539    0.06687    0.01604        251        640:  75% 6/8 [00:01<00:00,  3.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04528     0.0663     0.0162        184        640:  88% 7/8 [00:01<00:00,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04507     0.0656    0.01631        193        640: 100% 8/8 [00:02<00:00,  3.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.90it/s]
#                    all        128        929      0.733      0.645      0.733      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04488     0.0617    0.02394        170        640:  12% 1/8 [00:00<00:01,  3.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04242    0.06038    0.01826        202        640:  25% 2/8 [00:00<00:01,  3.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04176    0.05809    0.01751        169        640:  38% 3/8 [00:00<00:01,  3.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04303    0.05972    0.01753        209        640:  50% 4/8 [00:01<00:01,  3.83it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04392      0.066    0.01701        328        640:  62% 5/8 [00:01<00:00,  3.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G     0.0445    0.06547    0.01778        252        640:  75% 6/8 [00:01<00:00,  3.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04376    0.06194    0.01738        125        640:  88% 7/8 [00:01<00:00,  3.55it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04383    0.06209    0.01732        225        640: 100% 8/8 [00:02<00:00,  3.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.56it/s]
#                    all        128        929      0.759      0.643      0.754      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04041    0.04643    0.01356        166        640:  12% 1/8 [00:00<00:02,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04241    0.05219    0.01217        195        640:  25% 2/8 [00:00<00:01,  3.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G     0.0435    0.05565    0.01361        215        640:  38% 3/8 [00:00<00:01,  3.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04368    0.05314    0.01396        143        640:  50% 4/8 [00:01<00:01,  3.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04296    0.05456    0.01419        181        640:  62% 5/8 [00:01<00:01,  2.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04334     0.0532     0.0154        148        640:  75% 6/8 [00:02<00:00,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04302    0.05461    0.01539        235        640:  88% 7/8 [00:02<00:00,  1.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04344    0.05496    0.01539        199        640: 100% 8/8 [00:03<00:00,  2.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.09it/s]
#                    all        128        929      0.728      0.689      0.764       0.51
#
# 5 epochs completed in 0.013 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.8MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.06it/s]
#                    all        128        929      0.729       0.69      0.764       0.51
#                 person        128        254      0.841      0.713       0.81      0.539
#                bicycle        128          6          1      0.667      0.808      0.392
#                    car        128         46      0.681      0.457       0.58      0.242
#             motorcycle        128          5      0.774          1      0.928      0.702
#               airplane        128          6      0.926          1      0.995      0.707
#                    bus        128          7      0.659      0.714      0.722       0.65
#                  train        128          3      0.622      0.577       0.83      0.496
#                  truck        128         12      0.764        0.5      0.557      0.296
#                   boat        128          6      0.868      0.333      0.507      0.213
#          traffic light        128         14      0.801      0.288      0.422      0.232
#              stop sign        128          2      0.738          1      0.995      0.846
#                  bench        128          9      0.618      0.667       0.68      0.312
#                   bird        128         16      0.908          1      0.995      0.662
#                    cat        128          4      0.836          1      0.995      0.821
#                    dog        128          9          1      0.688      0.955      0.706
#                  horse        128          2      0.779          1      0.995      0.647
#               elephant        128         17      0.962      0.882      0.936      0.719
#                   bear        128          1      0.666          1      0.995      0.995
#                  zebra        128          4      0.865          1      0.995       0.91
#                giraffe        128          9      0.836      0.889      0.951      0.724
#               backpack        128          6      0.705      0.667      0.787      0.365
#               umbrella        128         18      0.808      0.703      0.894      0.514
#                handbag        128         19      0.662      0.316      0.415       0.24
#                    tie        128          7      0.742      0.714      0.822      0.515
#               suitcase        128          4      0.812          1      0.995      0.592
#                frisbee        128          5      0.704        0.8        0.8       0.66
#                   skis        128          1      0.647          1      0.995      0.398
#              snowboard        128          7      0.845      0.714      0.876      0.591
#            sports ball        128          6      0.599      0.667      0.602      0.324
#                   kite        128         10      0.561        0.7      0.582      0.226
#           baseball bat        128          4      0.531        0.5      0.528      0.189
#         baseball glove        128          7      0.533      0.429      0.475        0.3
#             skateboard        128          5      0.728      0.547      0.686      0.471
#          tennis racket        128          7       0.53      0.489       0.55      0.305
#                 bottle        128         18      0.543      0.444      0.567      0.269
#             wine glass        128         16       0.68      0.938      0.886      0.472
#                    cup        128         36      0.739       0.75      0.847      0.539
#                   fork        128          6          1      0.316      0.508      0.282
#                  knife        128         16      0.742      0.625      0.714      0.418
#                  spoon        128         22      0.612      0.502      0.618      0.358
#                   bowl        128         28      0.667      0.607      0.748      0.571
#                 banana        128          1      0.825          1      0.995      0.207
#               sandwich        128          2          1          0       0.39      0.337
#                 orange        128          4      0.592          1      0.995      0.652
#               broccoli        128         11      0.237      0.545      0.548       0.38
#                 carrot        128         24      0.592      0.875      0.786      0.532
#                hot dog        128          2      0.391          1      0.995       0.92
#                  pizza        128          5      0.818        0.8      0.962      0.716
#                  donut        128         14      0.634          1       0.95      0.834
#                   cake        128          4      0.859          1      0.995      0.846
#                  chair        128         35      0.564      0.686      0.626      0.341
#                  couch        128          6          1      0.776      0.895      0.552
#           potted plant        128         14      0.693      0.857      0.842      0.506
#                    bed        128          3      0.882      0.667      0.913      0.614
#           dining table        128         13       0.74      0.439      0.584      0.349
#                 toilet        128          2      0.748          1      0.995      0.846
#                     tv        128          2      0.674          1      0.995      0.895
#                 laptop        128          3          1          0       0.83      0.482
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.624       0.63      0.549
#             cell phone        128          8      0.482      0.375      0.395      0.218
#              microwave        128          3       0.79          1      0.995        0.8
#                   oven        128          5      0.339        0.4      0.435      0.275
#                   sink        128          6      0.422       0.37      0.461      0.337
#           refrigerator        128          5      0.567        0.8      0.806      0.546
#                   book        128         29      0.563      0.267      0.369       0.19
#                  clock        128          9      0.781      0.889       0.93      0.723
#                   vase        128          2      0.449          1      0.995      0.821
#               scissors        128          1          1          0      0.497      0.104
#             teddy bear        128         21      0.809      0.806      0.864      0.553
#             toothbrush        128          5      0.763          1      0.995       0.67
# Results saved to runs/train/exp4
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/f2449089a6f241a08c8e07861c81bebf
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.5215718746185303, 2.5443503856658936)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6835440624486755, 0.7638775005200609)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.457556602492091, 0.5102440527964537)
# COMET INFO:     metrics/precision [10]    : (0.6791493683461854, 0.7588899757733395)
# COMET INFO:     metrics/recall [10]       : (0.605375524096936, 0.6892090470681517)
# COMET INFO:     train/box_loss [10]       : (0.043435562402009964, 0.04529991000890732)
# COMET INFO:     train/cls_loss [10]       : (0.015392707660794258, 0.018179820850491524)
# COMET INFO:     train/obj_loss [10]       : (0.054962024092674255, 0.07189694046974182)
# COMET INFO:     val/box_loss [10]         : (0.039035994559526443, 0.041134096682071686)
# COMET INFO:     val/cls_loss [10]         : (0.007620334625244141, 0.010472774505615234)
# COMET INFO:     val/obj_loss [10]         : (0.03592967987060547, 0.03827667236328125)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/f2449089a6f241a08c8e07861c81bebf
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp4
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.88 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# ### Controlling the number of Prediction Images logged to Comet
#
# When logging predictions from YOLOv5, Comet will log the images associated with each set of predictions. By default a maximum of 100 validation images are logged. You can increase or decrease this number using the `COMET_MAX_IMAGE_UPLOADS` environment variable.

# %%
# !env COMET_MAX_IMAGE_UPLOADS=200 python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1
# Out:
# 2025-01-10 19:11:23.378746: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:11:23.399075: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:11:23.405785: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/94e9c6e2a49d442f8123f445b88490f0
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# WARNING ⚠️ NMS time limit 0.550s exceeded
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp5/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:03<00:22,  3.14s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:03<00:09,  1.54s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:04<00:05,  1.04s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:04<00:03,  1.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:05<00:02,  1.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:05<00:01,  1.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:06<00:00,  1.71it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:06<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:11<00:00,  2.98s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:02,  2.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04263    0.07197    0.01398        245        640:  25% 2/8 [00:00<00:02,  2.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04406    0.07894    0.01572        286        640:  38% 3/8 [00:01<00:02,  2.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04423    0.07648    0.01579        233        640:  50% 4/8 [00:01<00:01,  2.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04478    0.07575    0.01688        249        640:  62% 5/8 [00:02<00:01,  2.32it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04428     0.0732    0.01676        195        640:  75% 6/8 [00:02<00:00,  2.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04435    0.07369    0.01683        267        640:  88% 7/8 [00:03<00:00,  2.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04366     0.0719    0.01638        199        640: 100% 8/8 [00:03<00:00,  2.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:13<00:00,  3.47s/it]
#                    all        128        929      0.723      0.621       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04583    0.06229    0.01254        237        640:  12% 1/8 [00:00<00:02,  3.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04489    0.05657    0.01523        185        640:  25% 2/8 [00:00<00:01,  3.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0441    0.05478    0.01548        162        640:  38% 3/8 [00:00<00:01,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0453    0.06179    0.01648        303        640:  50% 4/8 [00:01<00:01,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04536    0.06484    0.01636        226        640:  62% 5/8 [00:01<00:00,  3.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04539    0.06687    0.01604        251        640:  75% 6/8 [00:01<00:00,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04528     0.0663     0.0162        184        640:  88% 7/8 [00:01<00:00,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04507     0.0656    0.01631        193        640: 100% 8/8 [00:02<00:00,  3.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.38s/it]
#                    all        128        929      0.733      0.645      0.733      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04488     0.0617    0.02394        170        640:  12% 1/8 [00:00<00:02,  3.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04242    0.06038    0.01826        202        640:  25% 2/8 [00:00<00:01,  3.36it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04176    0.05809    0.01751        169        640:  38% 3/8 [00:00<00:01,  3.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04303    0.05972    0.01753        209        640:  50% 4/8 [00:01<00:01,  3.24it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04392      0.066    0.01701        328        640:  62% 5/8 [00:01<00:00,  3.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G     0.0445    0.06547    0.01778        252        640:  75% 6/8 [00:01<00:00,  3.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04376    0.06194    0.01738        125        640:  88% 7/8 [00:02<00:00,  3.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04383    0.06209    0.01732        225        640: 100% 8/8 [00:02<00:00,  3.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.79it/s]
#                    all        128        929      0.759      0.643      0.754      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04041    0.04643    0.01356        166        640:  12% 1/8 [00:00<00:01,  3.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04241    0.05219    0.01217        195        640:  25% 2/8 [00:00<00:01,  4.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G     0.0435    0.05565    0.01361        215        640:  38% 3/8 [00:00<00:01,  3.60it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04368    0.05314    0.01396        143        640:  50% 4/8 [00:01<00:01,  3.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04296    0.05456    0.01419        181        640:  62% 5/8 [00:01<00:00,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04334     0.0532     0.0154        148        640:  75% 6/8 [00:01<00:00,  3.62it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04302    0.05461    0.01539        235        640:  88% 7/8 [00:01<00:00,  3.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04344    0.05496    0.01539        199        640: 100% 8/8 [00:02<00:00,  3.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.86it/s]
#                    all        128        929      0.728      0.689      0.764       0.51
#
# 5 epochs completed in 0.016 hours.
# Optimizer stripped from runs/train/exp5/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp5/weights/best.pt, 14.8MB
#
# Validating runs/train/exp5/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.45s/it]
#                    all        128        929      0.729       0.69      0.764       0.51
#                 person        128        254      0.841      0.713       0.81      0.539
#                bicycle        128          6          1      0.667      0.808      0.392
#                    car        128         46      0.681      0.457       0.58      0.242
#             motorcycle        128          5      0.774          1      0.928      0.702
#               airplane        128          6      0.926          1      0.995      0.707
#                    bus        128          7      0.659      0.714      0.722       0.65
#                  train        128          3      0.622      0.577       0.83      0.496
#                  truck        128         12      0.764        0.5      0.557      0.296
#                   boat        128          6      0.868      0.333      0.507      0.213
#          traffic light        128         14      0.801      0.288      0.422      0.232
#              stop sign        128          2      0.738          1      0.995      0.846
#                  bench        128          9      0.618      0.667       0.68      0.312
#                   bird        128         16      0.908          1      0.995      0.662
#                    cat        128          4      0.836          1      0.995      0.821
#                    dog        128          9          1      0.688      0.955      0.706
#                  horse        128          2      0.779          1      0.995      0.647
#               elephant        128         17      0.962      0.882      0.936      0.719
#                   bear        128          1      0.666          1      0.995      0.995
#                  zebra        128          4      0.865          1      0.995       0.91
#                giraffe        128          9      0.836      0.889      0.951      0.724
#               backpack        128          6      0.705      0.667      0.787      0.365
#               umbrella        128         18      0.808      0.703      0.894      0.514
#                handbag        128         19      0.662      0.316      0.415       0.24
#                    tie        128          7      0.742      0.714      0.822      0.515
#               suitcase        128          4      0.812          1      0.995      0.592
#                frisbee        128          5      0.704        0.8        0.8       0.66
#                   skis        128          1      0.647          1      0.995      0.398
#              snowboard        128          7      0.845      0.714      0.876      0.591
#            sports ball        128          6      0.599      0.667      0.602      0.324
#                   kite        128         10      0.561        0.7      0.582      0.226
#           baseball bat        128          4      0.531        0.5      0.528      0.189
#         baseball glove        128          7      0.533      0.429      0.475        0.3
#             skateboard        128          5      0.728      0.547      0.686      0.471
#          tennis racket        128          7       0.53      0.489       0.55      0.305
#                 bottle        128         18      0.543      0.444      0.567      0.269
#             wine glass        128         16       0.68      0.938      0.886      0.472
#                    cup        128         36      0.739       0.75      0.847      0.539
#                   fork        128          6          1      0.316      0.508      0.282
#                  knife        128         16      0.742      0.625      0.714      0.418
#                  spoon        128         22      0.612      0.502      0.618      0.358
#                   bowl        128         28      0.667      0.607      0.748      0.571
#                 banana        128          1      0.825          1      0.995      0.207
#               sandwich        128          2          1          0       0.39      0.337
#                 orange        128          4      0.592          1      0.995      0.652
#               broccoli        128         11      0.237      0.545      0.548       0.38
#                 carrot        128         24      0.592      0.875      0.786      0.532
#                hot dog        128          2      0.391          1      0.995       0.92
#                  pizza        128          5      0.818        0.8      0.962      0.716
#                  donut        128         14      0.634          1       0.95      0.834
#                   cake        128          4      0.859          1      0.995      0.846
#                  chair        128         35      0.564      0.686      0.626      0.341
#                  couch        128          6          1      0.776      0.895      0.552
#           potted plant        128         14      0.693      0.857      0.842      0.506
#                    bed        128          3      0.882      0.667      0.913      0.614
#           dining table        128         13       0.74      0.439      0.584      0.349
#                 toilet        128          2      0.748          1      0.995      0.846
#                     tv        128          2      0.674          1      0.995      0.895
#                 laptop        128          3          1          0       0.83      0.482
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.624       0.63      0.549
#             cell phone        128          8      0.482      0.375      0.395      0.218
#              microwave        128          3       0.79          1      0.995        0.8
#                   oven        128          5      0.339        0.4      0.435      0.275
#                   sink        128          6      0.422       0.37      0.461      0.337
#           refrigerator        128          5      0.567        0.8      0.806      0.546
#                   book        128         29      0.563      0.267      0.369       0.19
#                  clock        128          9      0.781      0.889       0.93      0.723
#                   vase        128          2      0.449          1      0.995      0.821
#               scissors        128          1          1          0      0.497      0.104
#             teddy bear        128         21      0.809      0.806      0.864      0.553
#             toothbrush        128          5      0.763          1      0.995       0.67
# Results saved to runs/train/exp5
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/94e9c6e2a49d442f8123f445b88490f0
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.5215718746185303, 2.5443503856658936)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6835440624486755, 0.7638775005200609)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.457556602492091, 0.5102440527964537)
# COMET INFO:     metrics/precision [10]    : (0.6791493683461854, 0.7588899757733395)
# COMET INFO:     metrics/recall [10]       : (0.605375524096936, 0.6892090470681517)
# COMET INFO:     train/box_loss [10]       : (0.043435562402009964, 0.04529991000890732)
# COMET INFO:     train/cls_loss [10]       : (0.015392707660794258, 0.018179820850491524)
# COMET INFO:     train/obj_loss [10]       : (0.054962024092674255, 0.07189694046974182)
# COMET INFO:     val/box_loss [10]         : (0.039035994559526443, 0.041134096682071686)
# COMET INFO:     val/cls_loss [10]         : (0.007620334625244141, 0.010472774505615234)
# COMET INFO:     val/obj_loss [10]         : (0.03592967987060547, 0.03827667236328125)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/94e9c6e2a49d442f8123f445b88490f0
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 200
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp5
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.88 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 206
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# ### Logging Class Level Metrics
#
# Use the `COMET_LOG_PER_CLASS_METRICS` environment variable to log mAP, precision, recall, f1 for each class.

# %%
# !env COMET_LOG_PER_CLASS_METRICS=true python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--bbox_interval 1 \
--weights yolov5s.pt
# Out:
# 2025-01-10 19:13:25.298812: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:13:25.319004: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:13:25.325029: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/6d8fb9f2d7684995a36aba33e5408c03
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp6/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp6
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:02<00:19,  2.73s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:03<00:08,  1.34s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:03<00:04,  1.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:03<00:02,  1.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:04<00:02,  1.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:05<00:01,  1.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:05<00:00,  1.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:05<00:00,  1.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:12<00:00,  3.15s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:02,  3.17it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04263    0.07197    0.01398        245        640:  25% 2/8 [00:00<00:01,  3.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04406    0.07894    0.01572        286        640:  38% 3/8 [00:01<00:01,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04423    0.07648    0.01579        233        640:  50% 4/8 [00:01<00:01,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04478    0.07575    0.01688        249        640:  62% 5/8 [00:01<00:01,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04428     0.0732    0.01676        195        640:  75% 6/8 [00:01<00:00,  3.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04435    0.07369    0.01683        267        640:  88% 7/8 [00:02<00:00,  3.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04366     0.0719    0.01638        199        640: 100% 8/8 [00:02<00:00,  3.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.25s/it]
#                    all        128        929      0.723      0.621       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04583    0.06229    0.01254        237        640:  12% 1/8 [00:00<00:01,  3.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04489    0.05657    0.01523        185        640:  25% 2/8 [00:00<00:01,  3.79it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0441    0.05478    0.01548        162        640:  38% 3/8 [00:00<00:01,  3.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0453    0.06179    0.01648        303        640:  50% 4/8 [00:01<00:01,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04536    0.06484    0.01636        226        640:  62% 5/8 [00:01<00:00,  3.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04539    0.06687    0.01604        251        640:  75% 6/8 [00:01<00:00,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04528     0.0663     0.0162        184        640:  88% 7/8 [00:02<00:00,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04507     0.0656    0.01631        193        640: 100% 8/8 [00:02<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.99it/s]
#                    all        128        929      0.733      0.645      0.733      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04488     0.0617    0.02394        170        640:  12% 1/8 [00:00<00:01,  3.69it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04242    0.06038    0.01826        202        640:  25% 2/8 [00:00<00:01,  3.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04176    0.05809    0.01751        169        640:  38% 3/8 [00:00<00:01,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04303    0.05972    0.01753        209        640:  50% 4/8 [00:01<00:01,  3.59it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04392      0.066    0.01701        328        640:  62% 5/8 [00:01<00:00,  3.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G     0.0445    0.06547    0.01778        252        640:  75% 6/8 [00:01<00:00,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04376    0.06194    0.01738        125        640:  88% 7/8 [00:02<00:00,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04383    0.06209    0.01732        225        640: 100% 8/8 [00:02<00:00,  3.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.86it/s]
#                    all        128        929      0.759      0.643      0.754      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04041    0.04643    0.01356        166        640:  12% 1/8 [00:00<00:02,  3.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04241    0.05219    0.01217        195        640:  25% 2/8 [00:00<00:01,  3.09it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G     0.0435    0.05565    0.01361        215        640:  38% 3/8 [00:01<00:01,  2.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04368    0.05314    0.01396        143        640:  50% 4/8 [00:01<00:01,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04296    0.05456    0.01419        181        640:  62% 5/8 [00:01<00:01,  2.78it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04334     0.0532     0.0154        148        640:  75% 6/8 [00:02<00:00,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04302    0.05461    0.01539        235        640:  88% 7/8 [00:02<00:00,  2.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04344    0.05496    0.01539        199        640: 100% 8/8 [00:03<00:00,  2.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.03s/it]
#                    all        128        929      0.728      0.689      0.764       0.51
#
# 5 epochs completed in 0.013 hours.
# Optimizer stripped from runs/train/exp6/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp6/weights/best.pt, 14.8MB
#
# Validating runs/train/exp6/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.07it/s]
#                    all        128        929      0.729       0.69      0.764       0.51
#                 person        128        254      0.841      0.713       0.81      0.539
#                bicycle        128          6          1      0.667      0.808      0.392
#                    car        128         46      0.681      0.457       0.58      0.242
#             motorcycle        128          5      0.774          1      0.928      0.702
#               airplane        128          6      0.926          1      0.995      0.707
#                    bus        128          7      0.659      0.714      0.722       0.65
#                  train        128          3      0.622      0.577       0.83      0.496
#                  truck        128         12      0.764        0.5      0.557      0.296
#                   boat        128          6      0.868      0.333      0.507      0.213
#          traffic light        128         14      0.801      0.288      0.422      0.232
#              stop sign        128          2      0.738          1      0.995      0.846
#                  bench        128          9      0.618      0.667       0.68      0.312
#                   bird        128         16      0.908          1      0.995      0.662
#                    cat        128          4      0.836          1      0.995      0.821
#                    dog        128          9          1      0.688      0.955      0.706
#                  horse        128          2      0.779          1      0.995      0.647
#               elephant        128         17      0.962      0.882      0.936      0.719
#                   bear        128          1      0.666          1      0.995      0.995
#                  zebra        128          4      0.865          1      0.995       0.91
#                giraffe        128          9      0.836      0.889      0.951      0.724
#               backpack        128          6      0.705      0.667      0.787      0.365
#               umbrella        128         18      0.808      0.703      0.894      0.514
#                handbag        128         19      0.662      0.316      0.415       0.24
#                    tie        128          7      0.742      0.714      0.822      0.515
#               suitcase        128          4      0.812          1      0.995      0.592
#                frisbee        128          5      0.704        0.8        0.8       0.66
#                   skis        128          1      0.647          1      0.995      0.398
#              snowboard        128          7      0.845      0.714      0.876      0.591
#            sports ball        128          6      0.599      0.667      0.602      0.324
#                   kite        128         10      0.561        0.7      0.582      0.226
#           baseball bat        128          4      0.531        0.5      0.528      0.189
#         baseball glove        128          7      0.533      0.429      0.475        0.3
#             skateboard        128          5      0.728      0.547      0.686      0.471
#          tennis racket        128          7       0.53      0.489       0.55      0.305
#                 bottle        128         18      0.543      0.444      0.567      0.269
#             wine glass        128         16       0.68      0.938      0.886      0.472
#                    cup        128         36      0.739       0.75      0.847      0.539
#                   fork        128          6          1      0.316      0.508      0.282
#                  knife        128         16      0.742      0.625      0.714      0.418
#                  spoon        128         22      0.612      0.502      0.618      0.358
#                   bowl        128         28      0.667      0.607      0.748      0.571
#                 banana        128          1      0.825          1      0.995      0.207
#               sandwich        128          2          1          0       0.39      0.337
#                 orange        128          4      0.592          1      0.995      0.652
#               broccoli        128         11      0.237      0.545      0.548       0.38
#                 carrot        128         24      0.592      0.875      0.786      0.532
#                hot dog        128          2      0.391          1      0.995       0.92
#                  pizza        128          5      0.818        0.8      0.962      0.716
#                  donut        128         14      0.634          1       0.95      0.834
#                   cake        128          4      0.859          1      0.995      0.846
#                  chair        128         35      0.564      0.686      0.626      0.341
#                  couch        128          6          1      0.776      0.895      0.552
#           potted plant        128         14      0.693      0.857      0.842      0.506
#                    bed        128          3      0.882      0.667      0.913      0.614
#           dining table        128         13       0.74      0.439      0.584      0.349
#                 toilet        128          2      0.748          1      0.995      0.846
#                     tv        128          2      0.674          1      0.995      0.895
#                 laptop        128          3          1          0       0.83      0.482
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.624       0.63      0.549
#             cell phone        128          8      0.482      0.375      0.395      0.218
#              microwave        128          3       0.79          1      0.995        0.8
#                   oven        128          5      0.339        0.4      0.435      0.275
#                   sink        128          6      0.422       0.37      0.461      0.337
#           refrigerator        128          5      0.567        0.8      0.806      0.546
#                   book        128         29      0.563      0.267      0.369       0.19
#                  clock        128          9      0.781      0.889       0.93      0.723
#                   vase        128          2      0.449          1      0.995      0.821
#               scissors        128          1          1          0      0.497      0.104
#             teddy bear        128         21      0.809      0.806      0.864      0.553
#             toothbrush        128          5      0.763          1      0.995       0.67
# Results saved to runs/train/exp6
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/6d8fb9f2d7684995a36aba33e5408c03
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     airplane_f1                    : 0.9614750026420469
# COMET INFO:     airplane_false_positives       : 0.0
# COMET INFO:     airplane_mAP@.5                : 0.995
# COMET INFO:     airplane_mAP@.5:.95            : 0.7071360747295968
# COMET INFO:     airplane_precision             : 0.9258082425440655
# COMET INFO:     airplane_recall                : 1.0
# COMET INFO:     airplane_support               : 6
# COMET INFO:     airplane_true_positives        : 6.0
# COMET INFO:     backpack_f1                    : 0.6853707831439264
# COMET INFO:     backpack_false_positives       : 2.0
# COMET INFO:     backpack_mAP@.5                : 0.7873665024630543
# COMET INFO:     backpack_mAP@.5:.95            : 0.36477293596059124
# COMET INFO:     backpack_precision             : 0.7051547273769496
# COMET INFO:     backpack_recall                : 0.6666666666666666
# COMET INFO:     backpack_support               : 6
# COMET INFO:     backpack_true_positives        : 4.0
# COMET INFO:     banana_f1                      : 0.9039389535401394
# COMET INFO:     banana_false_positives         : 0.0
# COMET INFO:     banana_mAP@.5                  : 0.995
# COMET INFO:     banana_mAP@.5:.95              : 0.20665384615384613
# COMET INFO:     banana_precision               : 0.8247158828057513
# COMET INFO:     banana_recall                  : 1.0
# COMET INFO:     banana_support                 : 1
# COMET INFO:     banana_true_positives          : 1.0
# COMET INFO:     baseball bat_f1                : 0.514978252980339
# COMET INFO:     baseball bat_false_positives   : 2.0
# COMET INFO:     baseball bat_mAP@.5            : 0.5283581081081079
# COMET INFO:     baseball bat_mAP@.5:.95        : 0.18908513513513514
# COMET INFO:     baseball bat_precision         : 0.5308816111285247
# COMET INFO:     baseball bat_recall            : 0.5
# COMET INFO:     baseball bat_support           : 4
# COMET INFO:     baseball bat_true_positives    : 2.0
# COMET INFO:     baseball glove_f1              : 0.47529686615688443
# COMET INFO:     baseball glove_false_positives : 3.0
# COMET INFO:     baseball glove_mAP@.5          : 0.47476191624154945
# COMET INFO:     baseball glove_mAP@.5:.95      : 0.2996353376648625
# COMET INFO:     baseball glove_precision       : 0.5334576288162786
# COMET INFO:     baseball glove_recall          : 0.42857142857142855
# COMET INFO:     baseball glove_support         : 7
# COMET INFO:     baseball glove_true_positives  : 3.0
# COMET INFO:     bear_f1                        : 0.7997992853564216
# COMET INFO:     bear_false_positives           : 1.0
# COMET INFO:     bear_mAP@.5                    : 0.995
# COMET INFO:     bear_mAP@.5:.95                : 0.9949999999999999
# COMET INFO:     bear_precision                 : 0.6663879429483066
# COMET INFO:     bear_recall                    : 1.0
# COMET INFO:     bear_support                   : 1
# COMET INFO:     bear_true_positives            : 1.0
# COMET INFO:     bed_f1                         : 0.7592587912236526
# COMET INFO:     bed_false_positives            : 0.0
# COMET INFO:     bed_mAP@.5                     : 0.9125000000000002
# COMET INFO:     bed_mAP@.5:.95                 : 0.6142569465648856
# COMET INFO:     bed_precision                  : 0.8817191677273981
# COMET INFO:     bed_recall                     : 0.6666666666666666
# COMET INFO:     bed_support                    : 3
# COMET INFO:     bed_true_positives             : 2.0
# COMET INFO:     bench_f1                       : 0.6412254726756681
# COMET INFO:     bench_false_positives          : 4.0
# COMET INFO:     bench_mAP@.5                   : 0.6799906609195403
# COMET INFO:     bench_mAP@.5:.95               : 0.31223401867993916
# COMET INFO:     bench_precision                : 0.6176546644683899
# COMET INFO:     bench_recall                   : 0.6666666666666666
# COMET INFO:     bench_support                  : 9
# COMET INFO:     bench_true_positives           : 6.0
# COMET INFO:     bicycle_f1                     : 0.7999641938958293
# COMET INFO:     bicycle_false_positives        : 0.0
# COMET INFO:     bicycle_mAP@.5                 : 0.8081557177615571
# COMET INFO:     bicycle_mAP@.5:.95             : 0.3923862804689228
# COMET INFO:     bicycle_precision              : 1.0
# COMET INFO:     bicycle_recall                 : 0.6666169374502707
# COMET INFO:     bicycle_support                : 6
# COMET INFO:     bicycle_true_positives         : 4.0
# COMET INFO:     bird_f1                        : 0.9519251577158903
# COMET INFO:     bird_false_positives           : 2.0
# COMET INFO:     bird_mAP@.5                    : 0.995
# COMET INFO:     bird_mAP@.5:.95                : 0.6615783530571993
# COMET INFO:     bird_precision                 : 0.9082606692870551
# COMET INFO:     bird_recall                    : 1.0
# COMET INFO:     bird_support                   : 16
# COMET INFO:     bird_true_positives            : 16.0
# COMET INFO:     boat_f1                        : 0.48169064661312383
# COMET INFO:     boat_false_positives           : 0.0
# COMET INFO:     boat_mAP@.5                    : 0.5069135617984991
# COMET INFO:     boat_mAP@.5:.95                : 0.212965779561379
# COMET INFO:     boat_precision                 : 0.8680235893526355
# COMET INFO:     boat_recall                    : 0.3333333333333333
# COMET INFO:     boat_support                   : 6
# COMET INFO:     boat_true_positives            : 2.0
# COMET INFO:     book_f1                        : 0.3626098916890611
# COMET INFO:     book_false_positives           : 6.0
# COMET INFO:     book_mAP@.5                    : 0.3692133685389699
# COMET INFO:     book_mAP@.5:.95                : 0.1903051002675839
# COMET INFO:     book_precision                 : 0.5632978709901787
# COMET INFO:     book_recall                    : 0.2673575432196122
# COMET INFO:     book_support                   : 29
# COMET INFO:     book_true_positives            : 8.0
# COMET INFO:     bottle_f1                      : 0.4887551940844175
# COMET INFO:     bottle_false_positives         : 7.0
# COMET INFO:     bottle_mAP@.5                  : 0.5665473100053845
# COMET INFO:     bottle_mAP@.5:.95              : 0.2688965559725037
# COMET INFO:     bottle_precision               : 0.5428798762132095
# COMET INFO:     bottle_recall                  : 0.4444444444444444
# COMET INFO:     bottle_support                 : 18
# COMET INFO:     bottle_true_positives          : 8.0
# COMET INFO:     bowl_f1                        : 0.6358384040615372
# COMET INFO:     bowl_false_positives           : 8.0
# COMET INFO:     bowl_mAP@.5                    : 0.7483798229720664
# COMET INFO:     bowl_mAP@.5:.95                : 0.5713834205524649
# COMET INFO:     bowl_precision                 : 0.6673810016913465
# COMET INFO:     bowl_recall                    : 0.6071428571428571
# COMET INFO:     bowl_support                   : 28
# COMET INFO:     bowl_true_positives            : 17.0
# COMET INFO:     broccoli_f1                    : 0.3303616853256934
# COMET INFO:     broccoli_false_positives       : 19.0
# COMET INFO:     broccoli_mAP@.5                : 0.5481658048155728
# COMET INFO:     broccoli_mAP@.5:.95            : 0.37991900298526754
# COMET INFO:     broccoli_precision             : 0.23693103359770026
# COMET INFO:     broccoli_recall                : 0.5454545454545454
# COMET INFO:     broccoli_support               : 11
# COMET INFO:     broccoli_true_positives        : 6.0
# COMET INFO:     bus_f1                         : 0.6857770598162417
# COMET INFO:     bus_false_positives            : 3.0
# COMET INFO:     bus_mAP@.5                     : 0.7216401869158877
# COMET INFO:     bus_mAP@.5:.95                 : 0.6504983333333333
# COMET INFO:     bus_precision                  : 0.6594567455223193
# COMET INFO:     bus_recall                     : 0.7142857142857143
# COMET INFO:     bus_support                    : 7
# COMET INFO:     bus_true_positives             : 5.0
# COMET INFO:     cake_f1                        : 0.9241284722216799
# COMET INFO:     cake_false_positives           : 1.0
# COMET INFO:     cake_mAP@.5                    : 0.995
# COMET INFO:     cake_mAP@.5:.95                : 0.8461842105263159
# COMET INFO:     cake_precision                 : 0.858958015303193
# COMET INFO:     cake_recall                    : 1.0
# COMET INFO:     cake_support                   : 4
# COMET INFO:     cake_true_positives            : 4.0
# COMET INFO:     car_f1                         : 0.546638683411104
# COMET INFO:     car_false_positives            : 10.0
# COMET INFO:     car_mAP@.5                     : 0.5796757531513803
# COMET INFO:     car_mAP@.5:.95                 : 0.24171842425283105
# COMET INFO:     car_precision                  : 0.681083997629263
# COMET INFO:     car_recall                     : 0.45652173913043476
# COMET INFO:     car_support                    : 46
# COMET INFO:     car_true_positives             : 21.0
# COMET INFO:     carrot_f1                      : 0.7064138990510609
# COMET INFO:     carrot_false_positives         : 14.0
# COMET INFO:     carrot_mAP@.5                  : 0.786497190504613
# COMET INFO:     carrot_mAP@.5:.95              : 0.5324492566409111
# COMET INFO:     carrot_precision               : 0.5922962763758783
# COMET INFO:     carrot_recall                  : 0.875
# COMET INFO:     carrot_support                 : 24
# COMET INFO:     carrot_true_positives          : 21.0
# COMET INFO:     cat_f1                         : 0.9106840527397694
# COMET INFO:     cat_false_positives            : 1.0
# COMET INFO:     cat_mAP@.5                     : 0.995
# COMET INFO:     cat_mAP@.5:.95                 : 0.8214574468085107
# COMET INFO:     cat_precision                  : 0.8360146154384838
# COMET INFO:     cat_recall                     : 1.0
# COMET INFO:     cat_support                    : 4
# COMET INFO:     cat_true_positives             : 4.0
# COMET INFO:     cell phone_f1                  : 0.4216943741649999
# COMET INFO:     cell phone_false_positives     : 3.0
# COMET INFO:     cell phone_mAP@.5              : 0.3945668410706412
# COMET INFO:     cell phone_mAP@.5:.95          : 0.21811757676550741
# COMET INFO:     cell phone_precision           : 0.4816712778213272
# COMET INFO:     cell phone_recall              : 0.375
# COMET INFO:     cell phone_support             : 8
# COMET INFO:     cell phone_true_positives      : 3.0
# COMET INFO:     chair_f1                       : 0.6189151646491906
# COMET INFO:     chair_false_positives          : 19.0
# COMET INFO:     chair_mAP@.5                   : 0.625739222616265
# COMET INFO:     chair_mAP@.5:.95               : 0.34052009551081897
# COMET INFO:     chair_precision                : 0.5639752942894518
# COMET INFO:     chair_recall                   : 0.6857142857142857
# COMET INFO:     chair_support                  : 35
# COMET INFO:     chair_true_positives           : 24.0
# COMET INFO:     clock_f1                       : 0.8317117994847238
# COMET INFO:     clock_false_positives          : 2.0
# COMET INFO:     clock_mAP@.5                   : 0.93
# COMET INFO:     clock_mAP@.5:.95               : 0.7229109328649492
# COMET INFO:     clock_precision                : 0.7814458973079663
# COMET INFO:     clock_recall                   : 0.8888888888888888
# COMET INFO:     clock_support                  : 9
# COMET INFO:     clock_true_positives           : 8.0
# COMET INFO:     couch_f1                       : 0.8737033653636883
# COMET INFO:     couch_false_positives          : 0.0
# COMET INFO:     couch_mAP@.5                   : 0.895
# COMET INFO:     couch_mAP@.5:.95               : 0.5524917484417898
# COMET INFO:     couch_precision                : 1.0
# COMET INFO:     couch_recall                   : 0.7757311337841409
# COMET INFO:     couch_support                  : 6
# COMET INFO:     couch_true_positives           : 5.0
# COMET INFO:     cup_f1                         : 0.7444604492637422
# COMET INFO:     cup_false_positives            : 10.0
# COMET INFO:     cup_mAP@.5                     : 0.8467652488791226
# COMET INFO:     cup_mAP@.5:.95                 : 0.5391836297307573
# COMET INFO:     cup_precision                  : 0.7390021295426701
# COMET INFO:     cup_recall                     : 0.75
# COMET INFO:     cup_support                    : 36
# COMET INFO:     cup_true_positives             : 27.0
# COMET INFO:     dining table_f1                : 0.5511825474664949
# COMET INFO:     dining table_false_positives   : 2.0
# COMET INFO:     dining table_mAP@.5            : 0.5836388850044868
# COMET INFO:     dining table_mAP@.5:.95        : 0.3491519734633749
# COMET INFO:     dining table_precision         : 0.7396543630096262
# COMET INFO:     dining table_recall            : 0.4392555510976564
# COMET INFO:     dining table_support           : 13
# COMET INFO:     dining table_true_positives    : 6.0
# COMET INFO:     dog_f1                         : 0.8153103818917012
# COMET INFO:     dog_false_positives            : 0.0
# COMET INFO:     dog_mAP@.5                     : 0.9550000000000001
# COMET INFO:     dog_mAP@.5:.95                 : 0.7055113737468671
# COMET INFO:     dog_precision                  : 1.0
# COMET INFO:     dog_recall                     : 0.6882058975021502
# COMET INFO:     dog_support                    : 9
# COMET INFO:     dog_true_positives             : 6.0
# COMET INFO:     donut_f1                       : 0.7760972716164258
# COMET INFO:     donut_false_positives          : 8.0
# COMET INFO:     donut_mAP@.5                   : 0.949888888888889
# COMET INFO:     donut_mAP@.5:.95               : 0.8338885656565658
# COMET INFO:     donut_precision                : 0.6341167918151703
# COMET INFO:     donut_recall                   : 1.0
# COMET INFO:     donut_support                  : 14
# COMET INFO:     donut_true_positives           : 14.0
# COMET INFO:     elephant_f1                    : 0.9203732871680574
# COMET INFO:     elephant_false_positives       : 1.0
# COMET INFO:     elephant_mAP@.5                : 0.9364977443609025
# COMET INFO:     elephant_mAP@.5:.95            : 0.7189662315564553
# COMET INFO:     elephant_precision             : 0.9618177499533431
# COMET INFO:     elephant_recall                : 0.8823529411764706
# COMET INFO:     elephant_support               : 17
# COMET INFO:     elephant_true_positives        : 15.0
# COMET INFO:     fork_f1                        : 0.48059649165477564
# COMET INFO:     fork_false_positives           : 0.0
# COMET INFO:     fork_mAP@.5                    : 0.5084573934837091
# COMET INFO:     fork_mAP@.5:.95                : 0.2821394817944281
# COMET INFO:     fork_precision                 : 1.0
# COMET INFO:     fork_recall                    : 0.31630602997500723
# COMET INFO:     fork_support                   : 6
# COMET INFO:     fork_true_positives            : 2.0
# COMET INFO:     frisbee_f1                     : 0.7489255494752733
# COMET INFO:     frisbee_false_positives        : 2.0
# COMET INFO:     frisbee_mAP@.5                 : 0.7996153846153848
# COMET INFO:     frisbee_mAP@.5:.95             : 0.6600769230769232
# COMET INFO:     frisbee_precision              : 0.7039812312669251
# COMET INFO:     frisbee_recall                 : 0.8
# COMET INFO:     frisbee_support                : 5
# COMET INFO:     frisbee_true_positives         : 4.0
# COMET INFO:     giraffe_f1                     : 0.8615781831421381
# COMET INFO:     giraffe_false_positives        : 2.0
# COMET INFO:     giraffe_mAP@.5                 : 0.9505555555555555
# COMET INFO:     giraffe_mAP@.5:.95             : 0.7236316666666667
# COMET INFO:     giraffe_precision              : 0.835895669882598
# COMET INFO:     giraffe_recall                 : 0.8888888888888888
# COMET INFO:     giraffe_support                : 9
# COMET INFO:     giraffe_true_positives         : 8.0
# COMET INFO:     handbag_f1                     : 0.4275760797780765
# COMET INFO:     handbag_false_positives        : 3.0
# COMET INFO:     handbag_mAP@.5                 : 0.4148803773219579
# COMET INFO:     handbag_mAP@.5:.95             : 0.2401595017812485
# COMET INFO:     handbag_precision              : 0.6618731726076359
# COMET INFO:     handbag_recall                 : 0.3157894736842105
# COMET INFO:     handbag_support                : 19
# COMET INFO:     handbag_true_positives         : 6.0
# COMET INFO:     horse_f1                       : 0.8758260975744386
# COMET INFO:     horse_false_positives          : 1.0
# COMET INFO:     horse_mAP@.5                   : 0.995
# COMET INFO:     horse_mAP@.5:.95               : 0.6472391304347827
# COMET INFO:     horse_precision                : 0.7790841752194408
# COMET INFO:     horse_recall                   : 1.0
# COMET INFO:     horse_support                  : 2
# COMET INFO:     horse_true_positives           : 2.0
# COMET INFO:     hot dog_f1                     : 0.5622519269773686
# COMET INFO:     hot dog_false_positives        : 3.0
# COMET INFO:     hot dog_mAP@.5                 : 0.995
# COMET INFO:     hot dog_mAP@.5:.95             : 0.9204431818181819
# COMET INFO:     hot dog_precision              : 0.3910642883320479
# COMET INFO:     hot dog_recall                 : 1.0
# COMET INFO:     hot dog_support                : 2
# COMET INFO:     hot dog_true_positives         : 2.0
# COMET INFO:     kite_f1                        : 0.6228473186505659
# COMET INFO:     kite_false_positives           : 5.0
# COMET INFO:     kite_mAP@.5                    : 0.5819283167812581
# COMET INFO:     kite_mAP@.5:.95                : 0.22616882744088632
# COMET INFO:     kite_precision                 : 0.561013470735693
# COMET INFO:     kite_recall                    : 0.7
# COMET INFO:     kite_support                   : 10
# COMET INFO:     kite_true_positives            : 7.0
# COMET INFO:     knife_f1                       : 0.6782848909548211
# COMET INFO:     knife_false_positives          : 3.0
# COMET INFO:     knife_mAP@.5                   : 0.7140763487826578
# COMET INFO:     knife_mAP@.5:.95               : 0.4184595112990759
# COMET INFO:     knife_precision                : 0.7415022799638185
# COMET INFO:     knife_recall                   : 0.625
# COMET INFO:     knife_support                  : 16
# COMET INFO:     knife_true_positives           : 10.0
# COMET INFO:     laptop_f1                      : 0.0
# COMET INFO:     laptop_false_positives         : 0.0
# COMET INFO:     laptop_mAP@.5                  : 0.8300000000000001
# COMET INFO:     laptop_mAP@.5:.95              : 0.48190554216867476
# COMET INFO:     laptop_precision               : 1.0
# COMET INFO:     laptop_recall                  : 0.0
# COMET INFO:     laptop_support                 : 3
# COMET INFO:     laptop_true_positives          : 0.0
# COMET INFO:     loss [4]                       : (1.5215718746185303, 2.5443503856658936)
# COMET INFO:     metrics/mAP_0.5 [10]           : (0.6835440624486755, 0.7638775005200609)
# COMET INFO:     metrics/mAP_0.5:0.95 [10]      : (0.457556602492091, 0.5102440527964537)
# COMET INFO:     metrics/precision [10]         : (0.6791493683461854, 0.7588899757733395)
# COMET INFO:     metrics/recall [10]            : (0.605375524096936, 0.6892090470681517)
# COMET INFO:     microwave_f1                   : 0.882395611217154
# COMET INFO:     microwave_false_positives      : 1.0
# COMET INFO:     microwave_mAP@.5               : 0.995
# COMET INFO:     microwave_mAP@.5:.95           : 0.8001081395348837
# COMET INFO:     microwave_precision            : 0.7895420061638699
# COMET INFO:     microwave_recall               : 1.0
# COMET INFO:     microwave_support              : 3
# COMET INFO:     microwave_true_positives       : 3.0
# COMET INFO:     motorcycle_f1                  : 0.8726703577608905
# COMET INFO:     motorcycle_false_positives     : 1.0
# COMET INFO:     motorcycle_mAP@.5              : 0.9283333333333333
# COMET INFO:     motorcycle_mAP@.5:.95          : 0.7020064102564103
# COMET INFO:     motorcycle_precision           : 0.7741039755040833
# COMET INFO:     motorcycle_recall              : 1.0
# COMET INFO:     motorcycle_support             : 5
# COMET INFO:     motorcycle_true_positives      : 5.0
# COMET INFO:     mouse_f1                       : 0.0
# COMET INFO:     mouse_false_positives          : 0.0
# COMET INFO:     mouse_mAP@.5                   : 0.0
# COMET INFO:     mouse_mAP@.5:.95               : 0.0
# COMET INFO:     mouse_precision                : 1.0
# COMET INFO:     mouse_recall                   : 0.0
# COMET INFO:     mouse_support                  : 2
# COMET INFO:     mouse_true_positives           : 0.0
# COMET INFO:     orange_f1                      : 0.7438533020401148
# COMET INFO:     orange_false_positives         : 3.0
# ...
# COMET INFO:     sink_false_positives           : 3.0
# COMET INFO:     sink_mAP@.5                    : 0.4610420224342876
# COMET INFO:     sink_mAP@.5:.95                : 0.3369482214967353
# COMET INFO:     sink_precision                 : 0.42203600659483015
# COMET INFO:     sink_recall                    : 0.3700600109913835
# COMET INFO:     sink_support                   : 6
# COMET INFO:     sink_true_positives            : 2.0
# COMET INFO:     skateboard_f1                  : 0.6242465635250507
# COMET INFO:     skateboard_false_positives     : 1.0
# COMET INFO:     skateboard_mAP@.5              : 0.6856015037593983
# COMET INFO:     skateboard_mAP@.5:.95          : 0.4707638035929517
# COMET INFO:     skateboard_precision           : 0.7277225257923104
# COMET INFO:     skateboard_recall              : 0.5465340619015452
# COMET INFO:     skateboard_support             : 5
# COMET INFO:     skateboard_true_positives      : 3.0
# COMET INFO:     skis_f1                        : 0.7857683060626491
# COMET INFO:     skis_false_positives           : 1.0
# COMET INFO:     skis_mAP@.5                    : 0.995
# COMET INFO:     skis_mAP@.5:.95                : 0.398
# COMET INFO:     skis_precision                 : 0.6471321000645791
# COMET INFO:     skis_recall                    : 1.0
# COMET INFO:     skis_support                   : 1
# COMET INFO:     skis_true_positives            : 1.0
# COMET INFO:     snowboard_f1                   : 0.7741392567497825
# COMET INFO:     snowboard_false_positives      : 1.0
# COMET INFO:     snowboard_mAP@.5               : 0.8758333333333334
# COMET INFO:     snowboard_mAP@.5:.95           : 0.5911842136752137
# COMET INFO:     snowboard_precision            : 0.8449410584827252
# COMET INFO:     snowboard_recall               : 0.7142857142857143
# COMET INFO:     snowboard_support              : 7
# COMET INFO:     snowboard_true_positives       : 5.0
# COMET INFO:     spoon_f1                       : 0.5518906306400855
# COMET INFO:     spoon_false_positives          : 7.0
# COMET INFO:     spoon_mAP@.5                   : 0.6180697803489779
# COMET INFO:     spoon_mAP@.5:.95               : 0.3584354839229479
# COMET INFO:     spoon_precision                : 0.6121930690177549
# COMET INFO:     spoon_recall                   : 0.5024027896368322
# COMET INFO:     spoon_support                  : 22
# COMET INFO:     spoon_true_positives           : 11.0
# COMET INFO:     sports ball_f1                 : 0.6312835094323026
# COMET INFO:     sports ball_false_positives    : 3.0
# COMET INFO:     sports ball_mAP@.5             : 0.6022521739130435
# COMET INFO:     sports ball_mAP@.5:.95         : 0.3237277681159421
# COMET INFO:     sports ball_precision          : 0.5994669589350928
# COMET INFO:     sports ball_recall             : 0.6666666666666666
# COMET INFO:     sports ball_support            : 6
# COMET INFO:     sports ball_true_positives     : 4.0
# COMET INFO:     stop sign_f1                   : 0.8495599510892761
# COMET INFO:     stop sign_false_positives      : 1.0
# COMET INFO:     stop sign_mAP@.5               : 0.995
# COMET INFO:     stop sign_mAP@.5:.95           : 0.8464107142857143
# COMET INFO:     stop sign_precision            : 0.7384652089378047
# COMET INFO:     stop sign_recall               : 1.0
# COMET INFO:     stop sign_support              : 2
# COMET INFO:     stop sign_true_positives       : 2.0
# COMET INFO:     suitcase_f1                    : 0.8964952770507587
# COMET INFO:     suitcase_false_positives       : 1.0
# COMET INFO:     suitcase_mAP@.5                : 0.995
# COMET INFO:     suitcase_mAP@.5:.95            : 0.5916168224299064
# COMET INFO:     suitcase_precision             : 0.8124072859921917
# COMET INFO:     suitcase_recall                : 1.0
# COMET INFO:     suitcase_support               : 4
# COMET INFO:     suitcase_true_positives        : 4.0
# COMET INFO:     teddy bear_f1                  : 0.8072831930230542
# COMET INFO:     teddy bear_false_positives     : 4.0
# COMET INFO:     teddy bear_mAP@.5              : 0.8643617318119734
# COMET INFO:     teddy bear_mAP@.5:.95          : 0.5530544816031838
# COMET INFO:     teddy bear_precision           : 0.808777856396904
# COMET INFO:     teddy bear_recall              : 0.805794043889282
# COMET INFO:     teddy bear_support             : 21
# COMET INFO:     teddy bear_true_positives      : 17.0
# COMET INFO:     tennis racket_f1               : 0.509132304789259
# COMET INFO:     tennis racket_false_positives  : 3.0
# COMET INFO:     tennis racket_mAP@.5           : 0.5504563909774438
# COMET INFO:     tennis racket_mAP@.5:.95       : 0.30530146024131455
# COMET INFO:     tennis racket_precision        : 0.5304466371133038
# COMET INFO:     tennis racket_recall           : 0.4894647027980361
# COMET INFO:     tennis racket_support          : 7
# COMET INFO:     tennis racket_true_positives   : 3.0
# COMET INFO:     tie_f1                         : 0.7277088219059139
# COMET INFO:     tie_false_positives            : 2.0
# COMET INFO:     tie_mAP@.5                     : 0.8219173913043478
# COMET INFO:     tie_mAP@.5:.95                 : 0.5154354642548482
# COMET INFO:     tie_precision                  : 0.7416460954024776
# COMET INFO:     tie_recall                     : 0.7142857142857143
# COMET INFO:     tie_support                    : 7
# COMET INFO:     tie_true_positives             : 5.0
# COMET INFO:     toilet_f1                      : 0.8559958160367654
# COMET INFO:     toilet_false_positives         : 1.0
# COMET INFO:     toilet_mAP@.5                  : 0.995
# COMET INFO:     toilet_mAP@.5:.95              : 0.8459322033898304
# COMET INFO:     toilet_precision               : 0.7482453543756226
# COMET INFO:     toilet_recall                  : 1.0
# COMET INFO:     toilet_support                 : 2
# COMET INFO:     toilet_true_positives          : 2.0
# COMET INFO:     toothbrush_f1                  : 0.8656924981643659
# COMET INFO:     toothbrush_false_positives     : 2.0
# COMET INFO:     toothbrush_mAP@.5              : 0.995
# COMET INFO:     toothbrush_mAP@.5:.95          : 0.670395390070922
# COMET INFO:     toothbrush_precision           : 0.763190313705435
# COMET INFO:     toothbrush_recall              : 1.0
# COMET INFO:     toothbrush_support             : 5
# COMET INFO:     toothbrush_true_positives      : 5.0
# COMET INFO:     traffic light_f1               : 0.4231458339145333
# COMET INFO:     traffic light_false_positives  : 1.0
# COMET INFO:     traffic light_mAP@.5           : 0.42157722616233256
# COMET INFO:     traffic light_mAP@.5:.95       : 0.2322316004584856
# COMET INFO:     traffic light_precision        : 0.8008499727797974
# COMET INFO:     traffic light_recall           : 0.28753565595670855
# COMET INFO:     traffic light_support          : 14
# COMET INFO:     traffic light_true_positives   : 4.0
# COMET INFO:     train/box_loss [10]            : (0.043435562402009964, 0.04529991000890732)
# COMET INFO:     train/cls_loss [10]            : (0.015392707660794258, 0.018179820850491524)
# COMET INFO:     train/obj_loss [10]            : (0.054962024092674255, 0.07189694046974182)
# COMET INFO:     train_f1                       : 0.5984746610647184
# COMET INFO:     train_false_positives          : 1.0
# COMET INFO:     train_mAP@.5                   : 0.8300000000000002
# COMET INFO:     train_mAP@.5:.95               : 0.4958185869565218
# COMET INFO:     train_precision                : 0.6217659887651574
# COMET INFO:     train_recall                   : 0.5768653108636483
# COMET INFO:     train_support                  : 3
# COMET INFO:     train_true_positives           : 2.0
# COMET INFO:     truck_f1                       : 0.6044170561812251
# COMET INFO:     truck_false_positives          : 2.0
# COMET INFO:     truck_mAP@.5                   : 0.5574631135707152
# COMET INFO:     truck_mAP@.5:.95               : 0.29641799952740355
# COMET INFO:     truck_precision                : 0.7639574274189659
# COMET INFO:     truck_recall                   : 0.5
# COMET INFO:     truck_support                  : 12
# COMET INFO:     truck_true_positives           : 6.0
# COMET INFO:     tv_f1                          : 0.8051632246723149
# COMET INFO:     tv_false_positives             : 1.0
# COMET INFO:     tv_mAP@.5                      : 0.995
# COMET INFO:     tv_mAP@.5:.95                  : 0.8955
# COMET INFO:     tv_precision                   : 0.6738688005744535
# COMET INFO:     tv_recall                      : 1.0
# COMET INFO:     tv_support                     : 2
# COMET INFO:     tv_true_positives              : 2.0
# COMET INFO:     umbrella_f1                    : 0.7522077646828311
# COMET INFO:     umbrella_false_positives       : 3.0
# COMET INFO:     umbrella_mAP@.5                : 0.8938205128205128
# COMET INFO:     umbrella_mAP@.5:.95            : 0.5135329609073698
# COMET INFO:     umbrella_precision             : 0.80826921448812
# COMET INFO:     umbrella_recall                : 0.7034187310583109
# COMET INFO:     umbrella_support               : 18
# COMET INFO:     umbrella_true_positives        : 13.0
# COMET INFO:     val/box_loss [10]              : (0.039035994559526443, 0.041134096682071686)
# COMET INFO:     val/cls_loss [10]              : (0.007620334625244141, 0.010472774505615234)
# COMET INFO:     val/obj_loss [10]              : (0.03592967987060547, 0.03827667236328125)
# COMET INFO:     vase_f1                        : 0.6193508389219881
# COMET INFO:     vase_false_positives           : 2.0
# COMET INFO:     vase_mAP@.5                    : 0.995
# COMET INFO:     vase_mAP@.5:.95                : 0.8209134615384615
# COMET INFO:     vase_precision                 : 0.44859393420295024
# COMET INFO:     vase_recall                    : 1.0
# COMET INFO:     vase_support                   : 2
# COMET INFO:     vase_true_positives            : 2.0
# COMET INFO:     wine glass_f1                  : 0.7879776438971792
# COMET INFO:     wine glass_false_positives     : 7.0
# COMET INFO:     wine glass_mAP@.5              : 0.8859626881055453
# COMET INFO:     wine glass_mAP@.5:.95          : 0.4717955929343979
# COMET INFO:     wine glass_precision           : 0.6795895567429612
# COMET INFO:     wine glass_recall              : 0.9375
# COMET INFO:     wine glass_support             : 16
# COMET INFO:     wine glass_true_positives      : 15.0
# COMET INFO:     x/lr0 [10]                     : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                     : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                     : (0.0007, 0.0013892000000000002)
# COMET INFO:     zebra_f1                       : 0.9276732473541288
# COMET INFO:     zebra_false_positives          : 1.0
# COMET INFO:     zebra_mAP@.5                   : 0.995
# COMET INFO:     zebra_mAP@.5:.95               : 0.9096500000000001
# COMET INFO:     zebra_precision                : 0.865103146093462
# COMET INFO:     zebra_recall                   : 1.0
# COMET INFO:     zebra_support                  : 4
# COMET INFO:     zebra_true_positives           : 4.0
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/6d8fb9f2d7684995a36aba33e5408c03
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : True
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp6
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (3.88 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:

# %% [markdown]
# ## Uploading a Dataset to Comet Artifacts
#
#
# If you would like to store your data using [Comet Artifacts](https://www.comet.com/docs/v2/guides/data-management/using-artifacts/#learn-more?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=comet_colab), you can do so using the `upload_dataset` flag.
#
# The dataset be organized in the way described in the [YOLOv5 documentation](https://docs.ultralytics.com/tutorials/train-custom-datasets/#3-organize-directories). The dataset config `yaml` file must follow the same format as that of the `coco128.yaml` file.

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data coco128.yaml \
--weights yolov5s.pt \
--bbox_interval 1 \
--upload_dataset "train"
# Out:
# 2025-01-10 19:15:00.455782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:15:00.475559: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:15:00.481908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=train, bbox_interval=1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-394-g86fd1ab2 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ever4ever-ing/comet-example-yolov5/0a4264304465406e9c8b333e45f2c518
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7235389 parameters, 7235389 gradients, 16.6 GFLOPs
#
# Transferred 349/349 items from yolov5s.pt
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#
# AutoAnchor: 4.27 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp7/labels.jpg...
# COMET ERROR: Error adding file to Artifact. Skipping file.
# COMET ERROR: Invalid file_data '/content/datasets/coco128/labels/train2017/000000000250.txt', must either be a valid file-path or an IO object
# COMET ERROR: Error adding file to Artifact. Skipping file.
# COMET ERROR: Invalid file_data '/content/datasets/coco128/labels/train2017/000000000508.txt', must either be a valid file-path or an IO object
# COMET INFO: Artifact 'yolov5-dataset' version 1.0.0 created
# COMET INFO: Scheduling the upload of 254 assets: 254 local assets for a size of 6.64 MB, and 0 remote assets (will be linked, not uploaded). This can take some time.
# COMET INFO: Artifact 'ever4ever-ing/yolov5-dataset:1.0.0' has started uploading asynchronously
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp7
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.72G    0.04758    0.05486    0.01542        211        640:  12% 1/8 [00:04<00:32,  4.58s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04567    0.06548    0.01513        242        640:  25% 2/8 [00:04<00:12,  2.11s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04559    0.06507    0.01713        234        640:  38% 3/8 [00:05<00:06,  1.30s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0451    0.06248     0.0179        182        640:  50% 4/8 [00:05<00:03,  1.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04499     0.0601    0.01852        158        640:  62% 5/8 [00:06<00:02,  1.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04553    0.06121    0.01792        215        640:  75% 6/8 [00:06<00:01,  1.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G    0.04581     0.0644    0.01782        292        640:  88% 7/8 [00:06<00:00,  1.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/4      3.76G     0.0453    0.06487    0.01818        194        640: 100% 8/8 [00:07<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:11<00:00,  2.92s/it]
#                    all        128        929      0.679      0.605      0.684      0.458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04551    0.06297    0.01211        196        640:  12% 1/8 [00:00<00:02,  2.72it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04263    0.07197    0.01398        245        640:  25% 2/8 [00:00<00:02,  2.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04406    0.07894    0.01572        286        640:  38% 3/8 [00:01<00:02,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04423    0.07648    0.01579        233        640:  50% 4/8 [00:01<00:01,  2.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# COMET INFO: Artifact 'ever4ever-ing/yolov5-dataset:1.0.0' has been fully uploaded successfully
#         1/4      4.61G    0.04478    0.07575    0.01688        249        640:  62% 5/8 [00:02<00:01,  2.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04428     0.0732    0.01676        195        640:  75% 6/8 [00:02<00:00,  2.71it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04435    0.07369    0.01683        267        640:  88% 7/8 [00:02<00:00,  2.82it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/4      4.61G    0.04366     0.0719    0.01638        199        640: 100% 8/8 [00:02<00:00,  2.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.10it/s]
#                    all        128        929      0.723      0.621       0.71      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04583    0.06229    0.01254        237        640:  12% 1/8 [00:00<00:02,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04489    0.05657    0.01523        185        640:  25% 2/8 [00:00<00:01,  3.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0441    0.05478    0.01548        162        640:  38% 3/8 [00:00<00:01,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G     0.0453    0.06179    0.01648        303        640:  50% 4/8 [00:01<00:01,  3.63it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04536    0.06484    0.01636        226        640:  62% 5/8 [00:01<00:00,  3.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04539    0.06687    0.01604        251        640:  75% 6/8 [00:01<00:00,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04528     0.0663     0.0162        184        640:  88% 7/8 [00:02<00:00,  3.12it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         2/4      4.61G    0.04507     0.0656    0.01631        193        640: 100% 8/8 [00:02<00:00,  3.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.79it/s]
#                    all        128        929      0.733      0.645      0.733      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04488     0.0617    0.02394        170        640:  12% 1/8 [00:00<00:02,  3.26it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04242    0.06038    0.01826        202        640:  25% 2/8 [00:00<00:01,  3.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04176    0.05809    0.01751        169        640:  38% 3/8 [00:00<00:01,  3.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04303    0.05972    0.01753        209        640:  50% 4/8 [00:01<00:01,  3.01it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04392      0.066    0.01701        328        640:  62% 5/8 [00:01<00:01,  2.73it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G     0.0445    0.06547    0.01778        252        640:  75% 6/8 [00:02<00:00,  2.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04376    0.06194    0.01738        125        640:  88% 7/8 [00:02<00:00,  2.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         3/4      4.61G    0.04383    0.06209    0.01732        225        640: 100% 8/8 [00:03<00:00,  2.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        128        929      0.759      0.643      0.754      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/8 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04041    0.04643    0.01356        166        640:  12% 1/8 [00:00<00:01,  3.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04241    0.05219    0.01217        195        640:  25% 2/8 [00:00<00:01,  3.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G     0.0435    0.05565    0.01361        215        640:  38% 3/8 [00:00<00:01,  3.70it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04368    0.05314    0.01396        143        640:  50% 4/8 [00:01<00:01,  3.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04296    0.05456    0.01419        181        640:  62% 5/8 [00:01<00:00,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04334     0.0532     0.0154        148        640:  75% 6/8 [00:01<00:00,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04302    0.05461    0.01539        235        640:  88% 7/8 [00:01<00:00,  3.37it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      4.61G    0.04344    0.05496    0.01539        199        640: 100% 8/8 [00:02<00:00,  3.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.85it/s]
#                    all        128        929      0.728      0.689      0.764       0.51
#
# 5 epochs completed in 0.013 hours.
# Optimizer stripped from runs/train/exp7/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/exp7/weights/best.pt, 14.8MB
#
# Validating runs/train/exp7/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.05it/s]
#                    all        128        929      0.729       0.69      0.764       0.51
#                 person        128        254      0.841      0.713       0.81      0.539
#                bicycle        128          6          1      0.667      0.808      0.392
#                    car        128         46      0.681      0.457       0.58      0.242
#             motorcycle        128          5      0.774          1      0.928      0.702
#               airplane        128          6      0.926          1      0.995      0.707
#                    bus        128          7      0.659      0.714      0.722       0.65
#                  train        128          3      0.622      0.577       0.83      0.496
#                  truck        128         12      0.764        0.5      0.557      0.296
#                   boat        128          6      0.868      0.333      0.507      0.213
#          traffic light        128         14      0.801      0.288      0.422      0.232
#              stop sign        128          2      0.738          1      0.995      0.846
#                  bench        128          9      0.618      0.667       0.68      0.312
#                   bird        128         16      0.908          1      0.995      0.662
#                    cat        128          4      0.836          1      0.995      0.821
#                    dog        128          9          1      0.688      0.955      0.706
#                  horse        128          2      0.779          1      0.995      0.647
#               elephant        128         17      0.962      0.882      0.936      0.719
#                   bear        128          1      0.666          1      0.995      0.995
#                  zebra        128          4      0.865          1      0.995       0.91
#                giraffe        128          9      0.836      0.889      0.951      0.724
#               backpack        128          6      0.705      0.667      0.787      0.365
#               umbrella        128         18      0.808      0.703      0.894      0.514
#                handbag        128         19      0.662      0.316      0.415       0.24
#                    tie        128          7      0.742      0.714      0.822      0.515
#               suitcase        128          4      0.812          1      0.995      0.592
#                frisbee        128          5      0.704        0.8        0.8       0.66
#                   skis        128          1      0.647          1      0.995      0.398
#              snowboard        128          7      0.845      0.714      0.876      0.591
#            sports ball        128          6      0.599      0.667      0.602      0.324
#                   kite        128         10      0.561        0.7      0.582      0.226
#           baseball bat        128          4      0.531        0.5      0.528      0.189
#         baseball glove        128          7      0.533      0.429      0.475        0.3
#             skateboard        128          5      0.728      0.547      0.686      0.471
#          tennis racket        128          7       0.53      0.489       0.55      0.305
#                 bottle        128         18      0.543      0.444      0.567      0.269
#             wine glass        128         16       0.68      0.938      0.886      0.472
#                    cup        128         36      0.739       0.75      0.847      0.539
#                   fork        128          6          1      0.316      0.508      0.282
#                  knife        128         16      0.742      0.625      0.714      0.418
#                  spoon        128         22      0.612      0.502      0.618      0.358
#                   bowl        128         28      0.667      0.607      0.748      0.571
#                 banana        128          1      0.825          1      0.995      0.207
#               sandwich        128          2          1          0       0.39      0.337
#                 orange        128          4      0.592          1      0.995      0.652
#               broccoli        128         11      0.237      0.545      0.548       0.38
#                 carrot        128         24      0.592      0.875      0.786      0.532
#                hot dog        128          2      0.391          1      0.995       0.92
#                  pizza        128          5      0.818        0.8      0.962      0.716
#                  donut        128         14      0.634          1       0.95      0.834
#                   cake        128          4      0.859          1      0.995      0.846
#                  chair        128         35      0.564      0.686      0.626      0.341
#                  couch        128          6          1      0.776      0.895      0.552
#           potted plant        128         14      0.693      0.857      0.842      0.506
#                    bed        128          3      0.882      0.667      0.913      0.614
#           dining table        128         13       0.74      0.439      0.584      0.349
#                 toilet        128          2      0.748          1      0.995      0.846
#                     tv        128          2      0.674          1      0.995      0.895
#                 laptop        128          3          1          0       0.83      0.482
#                  mouse        128          2          1          0          0          0
#                 remote        128          8          1      0.624       0.63      0.549
#             cell phone        128          8      0.482      0.375      0.395      0.218
#              microwave        128          3       0.79          1      0.995        0.8
#                   oven        128          5      0.339        0.4      0.435      0.275
#                   sink        128          6      0.422       0.37      0.461      0.337
#           refrigerator        128          5      0.567        0.8      0.806      0.546
#                   book        128         29      0.563      0.267      0.369       0.19
#                  clock        128          9      0.781      0.889       0.93      0.723
#                   vase        128          2      0.449          1      0.995      0.821
#               scissors        128          1          1          0      0.497      0.104
#             teddy bear        128         21      0.809      0.806      0.864      0.553
#             toothbrush        128          5      0.763          1      0.995       0.67
# Results saved to runs/train/exp7
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : https://www.comet.com/ever4ever-ing/comet-example-yolov5/0a4264304465406e9c8b333e45f2c518
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [4]                  : (1.5215718746185303, 2.5443503856658936)
# COMET INFO:     metrics/mAP_0.5 [10]      : (0.6835440624486755, 0.7638775005200609)
# COMET INFO:     metrics/mAP_0.5:0.95 [10] : (0.457556602492091, 0.5102440527964537)
# COMET INFO:     metrics/precision [10]    : (0.6791493683461854, 0.7588899757733395)
# COMET INFO:     metrics/recall [10]       : (0.605375524096936, 0.6892090470681517)
# COMET INFO:     train/box_loss [10]       : (0.043435562402009964, 0.04529991000890732)
# COMET INFO:     train/cls_loss [10]       : (0.015392707660794258, 0.018179820850491524)
# COMET INFO:     train/obj_loss [10]       : (0.054962024092674255, 0.07189694046974182)
# COMET INFO:     val/box_loss [10]         : (0.039035994559526443, 0.041134096682071686)
# COMET INFO:     val/cls_loss [10]         : (0.007620334625244141, 0.010472774505615234)
# COMET INFO:     val/obj_loss [10]         : (0.03592967987060547, 0.03827667236328125)
# COMET INFO:     x/lr0 [10]                : (0.0618112, 0.0937)
# COMET INFO:     x/lr1 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:     x/lr2 [10]                : (0.0007, 0.0013892000000000002)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     Run Path                    : ever4ever-ing/comet-example-yolov5/0a4264304465406e9c8b333e45f2c518
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.5
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data/hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs/train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs/train/exp7
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     artifact assets     : 254 (6.64 MB)
# COMET INFO:     artifacts           : 1
# COMET INFO:     asset               : 13 (3.88 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 106
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     os packages         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: All assets have been sent, waiting for delivery confirmation

# %% [markdown]
# You can find the uploaded dataset in the Artifacts tab in your Comet Workspace
# <img width="1073" alt="artifact-1" src="https://user-images.githubusercontent.com/7529846/186929193-162718bf-ec7b-4eb9-8c3b-86b3763ef8ea.png">
#
# You can preview the data directly in the Comet UI.
# <img width="1082" alt="artifact-2" src="https://user-images.githubusercontent.com/7529846/186929215-432c36a9-c109-4eb0-944b-84c2786590d6.png">
#
# Artifacts are versioned and also support adding metadata about the dataset. Comet will automatically log the metadata from your dataset `yaml` file
# <img width="963" alt="artifact-3" src="https://user-images.githubusercontent.com/7529846/186929256-9d44d6eb-1a19-42de-889a-bcbca3018f2e.png">

# %% [markdown]
# ### Using a saved Artifact
#
#
# If you would like to use a dataset from Comet Artifacts, set the `path` variable in your dataset `yaml` file to point to the following Artifact resource URL.
#
# ```
# # contents of artifact.yaml file
# path:"comet://<workspace name>/<artifact name>:<artifact version or alias>"
# ```
# Then pass this file to your training script

# %%
# !echo "path: \"comet://examples/yolov5-dataset:latest\"" >> /content/yolov5/data/artifact.yaml

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data /content/yolov5/data/artifact.yaml \
--bbox_interval 1 \
--weights yolov5s.pt \
# Out:
# 2025-01-10 19:17:00.079301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:17:00.113381: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:17:00.121239: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP] [--epochs EPOCHS]
#                 [--batch-size BATCH_SIZE] [--imgsz IMGSZ] [--rect] [--resume [RESUME]] [--nosave]
#                 [--noval] [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--evolve_population EVOLVE_POPULATION] [--resume_evolve RESUME_EVOLVE]
#                 [--bucket BUCKET] [--cache [CACHE]] [--image-weights] [--device DEVICE]
#                 [--multi-scale] [--single-cls] [--optimizer {SGD,Adam,AdamW}] [--sync-bn]
#                 [--workers WORKERS] [--project PROJECT] [--name NAME] [--exist-ok] [--quad]
#                 [--cos-lr] [--label-smoothing LABEL_SMOOTHING] [--patience PATIENCE]
#                 [--freeze FREEZE [FREEZE ...]] [--save-period SAVE_PERIOD] [--seed SEED]
#                 [--local_rank LOCAL_RANK] [--entity ENTITY] [--upload_dataset [UPLOAD_DATASET]]
#                 [--bbox_interval BBOX_INTERVAL] [--artifact_alias ARTIFACT_ALIAS]
#                 [--ndjson-console] [--ndjson-file]
# train.py: error: unrecognized arguments: \

# %% [markdown]
# Artifacts also allow you to track the lineage of data as it flows through your Experimentation workflow. Here you can see a graph that shows you all the experiments that have used your uploaded dataset.
# <img width="1391" alt="artifact-4" src="https://user-images.githubusercontent.com/7529846/186929264-4c4014fa-fe51-4f3c-a5c5-f6d24649b1b4.png">

# %% [markdown]
# ## Resuming a Training Run
#
# If your training run is interrupted for any reason, e.g. disrupted internet connection, you can resume the run using the `resume` flag and the Comet Run Path.
#
# The Run Path has the following format `comet://<your workspace name>/<your project name>/<experiment id>`.
#
# This will restore the run to its state before the interruption, which includes restoring the  model from a checkpoint, restoring all hyperparameters and training arguments and downloading Comet dataset Artifacts if they were used in the original run. The resumed run will continue logging to the existing Experiment in the Comet UI

# %%
# !python train.py \
--resume "comet://ever4ever-ing"
# Out:
# 2025-01-10 19:18:53.885196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-10 19:18:53.905115: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-10 19:18:53.911203: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=comet://ever4ever-ing, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 986, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 641, in main
#     if opt.resume and not check_comet_resume(opt) and not opt.evolve:
#   File "/content/yolov5/utils/loggers/comet/comet_utils.py", line 146, in check_comet_resume
#     set_opt_parameters(opt, experiment)
#   File "/content/yolov5/utils/loggers/comet/comet_utils.py", line 77, in set_opt_parameters
#     asset_list = experiment.get_asset_list()
# AttributeError: 'list' object has no attribute 'get_asset_list'
